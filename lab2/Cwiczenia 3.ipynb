# %% [markdown]
# Names.csv
# * Dodaj kolumnę z wartością czasu wykonania notatnika w formacie epoch
# * Dodaj kolumnę w której wyliczysz wzrost w stopach (feet)
# * Odpowiedz na pytanie jakie jest najpopularniesze imię?
# * Dodaj kolumnę i policz wiek aktorów
# * Usuń kolumny (bio, death_details)
# * Zmień nazwy kolumn - dodaj kapitalizaję i usuń _
# * Posortuj dataframe po imieniu rosnąco

# %%
import time
from pyspark.sql import functions as fun

# %%
filePath = "dbfs:/FileStore/tables/Files/names.csv"
namesDf = (spark.read
  .format("csv")
  .option("header","true")
  .option("inferSchema","true")
  .load(filePath))

current_epoch = int(time.time())            
namesDf = namesDf.withColumn("execution_time", fun.lit(current_epoch))


namesDf = namesDf.withColumn("height_feet", fun.round(namesDf['height'] * 0.0328, 2))


namesDf = namesDf.withColumn("first_name", fun.split(namesDf['name'], " ")[0])
the_most_popular_name = (namesDf
                         .groupBy('first_name')
                         .count()
                         .orderBy(fun.desc('count'))
                         .limit(1))
display(the_most_popular_name)


namesDf = namesDf.withColumn("date_of_birth",
    fun.coalesce(
        fun.to_date("date_of_birth", "yyyy-MM-dd"),
        fun.to_date("date_of_birth", "dd.MM.yyyy") 
    ))

namesDf = namesDf.withColumn("date_of_death",
    fun.coalesce(
        fun.to_date("date_of_death", "yyyy-MM-dd"),
        fun.to_date("date_of_death", "dd.MM.yyyy")
    ))

namesDf = namesDf.withColumn("age", fun.when(fun.col("date_of_death").isNotNull(), 
          fun.floor(fun.datediff("date_of_death", "date_of_birth") / 365.25))
          .otherwise(fun.floor(fun.datediff(fun.current_date(), "date_of_birth") / 365.25))
)


namesDf = namesDf.drop('bio', 'death_details')


for col in namesDf.columns:
  namesDf = namesDf.withColumnRenamed(col, col.capitalize().replace('_', ' '))


namesDf = namesDf.sort(fun.col('Name').asc())

display(namesDf.limit(20))
namesDf.explain(True)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>count</th></tr></thead><tbody><tr><td>John</td><td>873</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Imdb name id</th><th>Name</th><th>Birth name</th><th>Height</th><th>Birth details</th><th>Date of birth</th><th>Place of birth</th><th>Date of death</th><th>Place of death</th><th>Reason of death</th><th>Spouses string</th><th>Spouses</th><th>Divorces</th><th>Spouses with children</th><th>Children</th><th>Execution time</th><th>Height feet</th><th>First name</th><th>Age</th></tr></thead><tbody><tr><td>nm1001478</td><td>'Big' LeRoy Mobley</td><td>LeRoy King Mobley III</td><td>193</td><td>April 1, 1973 in Atlantic City, New Jersey, USA</td><td>1973-04-01</td><td>Atlantic City, New Jersey, USA</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1742317962</td><td>6.33</td><td>'Big'</td><td>51</td></tr><tr><td>nm0521811</td><td>'Ducky' Louie</td><td>Lawrence Louie</td><td>null</td><td>July 22, 1931 in Berkeley, California, USA</td><td>1931-07-22</td><td>Berkeley, California, USA</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1742317962</td><td>null</td><td>'Ducky'</td><td>93</td></tr><tr><td>nm0722372</td><td>'Little Billy' Rhodes</td><td>William H. Rhodes</td><td>null</td><td>February 1, 1895 in Illinois, USA</td><td>1895-02-01</td><td>Illinois, USA</td><td>1967-07-24</td><td>Hollywood, California, USA  </td><td>stroke</td><td>null</td><td>0</td><td>0</td><td>0</td><td>0</td><td>
place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                           +- Project [Imdb name id#11449, Name#11469, Birth name#11489, Height#11509, birth_details#11240 AS Birth details#11529, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                              +- Project [Imdb name id#11449, Name#11469, Birth name#11489, height#11238 AS Height#11509, birth_details#11240, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                                 +- Project [Imdb name id#11449, Name#11469, birth_name#11237 AS Birth name#11489, height#11238, birth_details#11240, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                                    +- Project [Imdb name id#11449, name#11236 AS Name#11469, birth_name#11237, height#11238, birth_details#11240, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                                       +- Project [imdb_name_id#11235 AS Imdb name id#11449, name#11236, birth_name#11237, height#11238, birth_details#11240, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                                          +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, birth_details#11240, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                                             +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, date_of_birth#11366, place_of_birth#11242, death_details#11243, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, CASE WHEN isnotnull(date_of_death#11387) THEN FLOOR((cast(datediff(date_of_death#11387, date_of_birth#11366) as double) / cast(365.25 as double))) ELSE FLOOR((cast(datediff(current_date(Some(Etc/UTC)), date_of_birth#11366) as double) / cast(365.25 as double))) END AS age#11408L]
#                                                                +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, date_of_birth#11366, place_of_birth#11242, death_details#11243, coalesce(to_date(date_of_death#11244, Some(yyyy-MM-dd), Some(Etc/UTC), false), to_date(date_of_death#11244, Some(dd.MM.yyyy), Some(Etc/UTC), false)) AS date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309]
#                                                                   +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, coalesce(to_date(date_of_birth#11241, Some(yyyy-MM-dd), Some(Etc/UTC), false), to_date(date_of_birth#11241, Some(dd.MM.yyyy), Some(Etc/UTC), false)) AS date_of_birth#11366, place_of_birth#11242, death_details#11243, date_of_death#11244, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309]
#                                                                      +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, date_of_birth#11241, place_of_birth#11242, death_details#11243, date_of_death#11244, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, split(name#11236,  , -1)[0] AS first_name#11309]
#                                                                         +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, date_of_birth#11241, place_of_birth#11242, death_details#11243, date_of_death#11244, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, round((cast(height#11238 as double) * 0.0328), 2) AS height_feet#11289]
#                                                                            +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, date_of_birth#11241, place_of_birth#11242, death_details#11243, date_of_death#11244, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251
spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                            +- Project [Imdb name id#11449, Name#11469, Birth name#11489, Height#11509, Birth details#11529, Date of birth#11549, Place of birth#11569, Date of death#11589, Place of death#11609, reason_of_death#11246 AS Reason of death#11629, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                               +- Project [Imdb name id#11449, Name#11469, Birth name#11489, Height#11509, Birth details#11529, Date of birth#11549, Place of birth#11569, Date of death#11589, place_of_death#11245 AS Place of death#11609, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                  +- Project [Imdb name id#11449, Name#11469, Birth name#11489, Height#11509, Birth details#11529, Date of birth#11549, Place of birth#11569, date_of_death#11387 AS Date of death#11589, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                     +- Project [Imdb name id#11449, Name#11469, Birth name#11489, Height#11509, Birth details#11529, Date of birth#11549, place_of_birth#11242 AS Place of birth#11569, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                        +- Project [Imdb name id#11449, Name#11469, Birth name#11489, Height#11509, Birth details#11529, date_of_birth#11366 AS Date of birth#11549, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                           +- Project [Imdb name id#11449, Name#11469, Birth name#11489, Height#11509, birth_details#11240 AS Birth details#11529, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                              +- Project [Imdb name id#11449, Name#11469, Birth name#11489, height#11238 AS Height#11509, birth_details#11240, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                                 +- Project [Imdb name id#11449, Name#11469, birth_name#11237 AS Birth name#11489, height#11238, birth_details#11240, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                                    +- Project [Imdb name id#11449, name#11236 AS Name#11469, birth_name#11237, height#11238, birth_details#11240, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                                       +- Project [imdb_name_id#11235 AS Imdb name id#11449, name#11236, birth_name#11237, height#11238, birth_details#11240, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                                          +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, birth_details#11240, date_of_birth#11366, place_of_birth#11242, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, age#11408L]
#                                                             +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, date_of_birth#11366, place_of_birth#11242, death_details#11243, date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309, CASE WHEN isnotnull(date_of_death#11387) THEN FLOOR((cast(datediff(date_of_death#11387, date_of_birth#11366) as double) / cast(365.25 as double))) ELSE FLOOR((cast(datediff(current_date(Some(Etc/UTC)), date_of_birth#11366) as double) / cast(365.25 as double))) END AS age#11408L]
#                                                                +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, date_of_birth#11366, place_of_birth#11242, death_details#11243, coalesce(to_date(date_of_death#11244, Some(yyyy-MM-dd), Some(Etc/UTC), false), to_date(date_of_death#11244, Some(dd.MM.yyyy), Some(Etc/UTC), false)) AS date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309]
#                                                                   +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, coalesce(to_date(date_of_birth#11241, Some(yyyy-MM-dd), Some(Etc/UTC), false), to_date(date_of_birth#11241, Some(dd.MM.yyyy), Some(Etc/UTC), false)) AS date_of_birth#11366, place_of_birth#11242, death_details#11243, date_of_death#11244, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, first_name#11309]
#                                                                      +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, date_of_birth#11241, place_of_birth#11242, death_details#11243, date_of_death#11244, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, height_feet#11289, split(name#11236,  , -1)[0] AS first_name#11309]
#                                                                         +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, date_of_birth#11241, place_of_birth#11242, death_details#11243, date_of_death#11244, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, execution_time#11269, round((cast(height#11238 as double) * 0.0328), 2) AS height_feet#11289]
#                                                                            +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, bio#11239, birth_details#11240, date_of_birth#11241, place_of_birth#11242, death_details#11243, date_of_death#11244, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, 1742317962 AS execution_time#11269]
#                                                                               +- Relation [imdb_name_id#11235,name#11236,birth_name#11237,height#11238,bio#11239,birth_details#11240,date_of_birth#11241,place_of_birth#11242,death_details#11243,date_of_death#11244,place_of_death#11245,reason_of_death#11246,spouses_string#11247,spouses#11248,divorces#11249,spouses_with_children#11250,children#11251] csv
#
# == Optimized Logical Plan ==
# Sort [Name#11469 ASC NULLS FIRST], true
# +- Project [imdb_name_id#11235 AS Imdb name id#11449, name#11236 AS Name#11469, birth_name#11237 AS Birth name#11489, height#11238 AS Height#11509, birth_details#11240 AS Birth details#11529, date_of_birth#11366 AS Date of birth#11549, place_of_birth#11242 AS Place of birth#11569, date_of_death#11387 AS Date of death#11589, place_of_death#11245 AS Place of death#11609, reason_of_death#11246 AS Reason of death#11629, spouses_string#11247 AS Spouses string#11649, spouses#11248 AS Spouses#11669, divorces#11249 AS Divorces#11689, spouses_with_children#11250 AS Spouses with children#11709, children#11251 AS Children#11729, 1742317962 AS Execution time#11749, height_feet#11289 AS Height feet#11769, first_name#11309 AS First name#11789, CASE WHEN isnotnull(date_of_death#11387) THEN FLOOR((cast(datediff(date_of_death#11387, date_of_birth#11366) as double) / 365.25)) ELSE FLOOR((cast(datediff(2025-03-18, date_of_birth#11366) as double) / 365.25)) END AS Age#11809L]
#    +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, birth_details#11240, coalesce(cast(gettimestamp(date_of_birth#11241, yyyy-MM-dd, TimestampType, Some(Etc/UTC), false) as date), cast(gettimestamp(date_of_birth#11241, dd.MM.yyyy, TimestampType, Some(Etc/UTC), false) as date)) AS date_of_birth#11366, place_of_birth#11242, coalesce(cast(gettimestamp(date_of_death#11244, yyyy-MM-dd, TimestampType, Some(Etc/UTC), false) as date), cast(gettimestamp(date_of_death#11244, dd.MM.yyyy, TimestampType, Some(Etc/UTC), false) as date)) AS date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, round((cast(height#11238 as double) * 0.0328), 2) AS height_feet#11289, split(name#11236,  , 2)[0] AS first_name#11309]
#       +- Relation [imdb_name_id#11235,name#11236,birth_name#11237,height#11238,bio#11239,birth_details#11240,date_of_birth#11241,place_of_birth#11242,death_details#11243,date_of_death#11244,place_of_death#11245,reason_of_death#11246,spouses_string#11247,spouses#11248,divorces#11249,spouses_with_children#11250,children#11251] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [Name#11469 ASC NULLS FIRST], true, 0
#    +- Exchange rangepartitioning(Name#11469 ASC NULLS FIRST, 200), ENSURE_REQUIREMENTS, [plan_id=3705]
#       +- Project [imdb_name_id#11235 AS Imdb name id#11449, name#11236 AS Name#11469, birth_name#11237 AS Birth name#11489, height#11238 AS Height#11509, birth_details#11240 AS Birth details#11529, date_of_birth#11366 AS Date of birth#11549, place_of_birth#11242 AS Place of birth#11569, date_of_death#11387 AS Date of death#11589, place_of_death#11245 AS Place of death#11609, reason_of_death#11246 AS Reason of death#11629, spouses_string#11247 AS Spouses string#11649, spouses#11248 AS Spouses#11669, divorces#11249 AS Divorces#11689, spouses_with_children#11250 AS Spouses with children#11709, children#11251 AS Children#11729, 1742317962 AS Execution time#11749, height_feet#11289 AS Height feet#11769, first_name#11309 AS First name#11789, CASE WHEN isnotnull(date_of_death#11387) THEN FLOOR((cast(datediff(date_of_death#11387, date_of_birth#11366) as double) / 365.25)) ELSE FLOOR((cast(datediff(2025-03-18, date_of_birth#11366) as double) / 365.25)) END AS Age#11809L]
#          +- Project [imdb_name_id#11235, name#11236, birth_name#11237, height#11238, birth_details#11240, coalesce(cast(gettimestamp(date_of_birth#11241, yyyy-MM-dd, TimestampType, Some(Etc/UTC), false) as date), cast(gettimestamp(date_of_birth#11241, dd.MM.yyyy, TimestampType, Some(Etc/UTC), false) as date)) AS date_of_birth#11366, place_of_birth#11242, coalesce(cast(gettimestamp(date_of_death#11244, yyyy-MM-dd, TimestampType, Some(Etc/UTC), false) as date), cast(gettimestamp(date_of_death#11244, dd.MM.yyyy, TimestampType, Some(Etc/UTC), false) as date)) AS date_of_death#11387, place_of_death#11245, reason_of_death#11246, spouses_string#11247, spouses#11248, divorces#11249, spouses_with_children#11250, children#11251, round((cast(height#11238 as double) * 0.0328), 2) AS height_feet#11289, split(name#11236,  , 2)[0] AS first_name#11309]
#             +- FileScan csv [imdb_name_id#11235,name#11236,birth_name#11237,height#11238,birth_details#11240,date_of_birth#11241,place_of_birth#11242,date_of_death#11244,place_of_death#11245,reason_of_death#11246,spouses_string#11247,spouses#11248,divorces#11249,spouses_with_children#11250,children#11251] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/FileStore/tables/Files/names.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<imdb_name_id:string,name:string,birth_name:string,height:int,birth_details:string,date_of_...

# %% [markdown]
# Movies.csv
# * Dodaj kolumnę z wartością czasu wykonania notatnika w formacie epoch
# * Dodaj kolumnę która wylicza ile lat upłynęło od publikacji filmu
# * Dodaj kolumnę która pokaże budżet filmu jako wartość numeryczną, (trzeba usunac znaki walut)
# * Usuń wiersze z dataframe gdzie wartości są null

# %%
filePath = "dbfs:/FileStore/tables/Files/movies.csv"
moviesDf = (spark.read.format("csv")
              .option("header","true")
              .option("inferSchema","true")
              .load(filePath))

current_epoch = int(time.time())
moviesDf = moviesDf.withColumn("execution_time", fun.lit(current_epoch))


moviesDf = moviesDf.withColumn('age', fun.when(
                                fun.col('year').isNotNull(), 
                                fun.year(fun.current_date()) - fun.col('year'))
                               .otherwise(None))


moviesDf = moviesDf.withColumn('budget_number', fun.regexp_replace
                               (fun.col('budget'), r'[^\d.]',''))

moviesDf = moviesDf.dropna()                               

display(moviesDf.limit(20))
moviesDf.explain(True)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>imdb_title_id</th><th>title</th><th>original_title</th><th>year</th><th>date_published</th><th>genre</th><th>duration</th><th>country</th><th>language</th><th>director</th><th>writer</th><th>production_company</th><th>actors</th><th>description</th><th>avg_vote</th><th>votes</th><th>budget</th><th>usa_gross_income</th><th>worlwide_gross_income</th><th>metascore</th><th>reviews_from_users</th><th>reviews_from_critics</th><th>execution_time</th><th>age</th><th>budget_number</th></tr></thead><tbody><tr><td>tt0017136</td><td>Metropolis</td><td>Metropolis</td><td>1927</td><td>01.10.1928</td><td>Drama, Sci-Fi</td><td>153</td><td>Germany</td><td>German</td><td>Fritz Lang</td><td>Thea von Harbou, Thea von Harbou</td><td>Universum Film (UFA)</td><td>Alfred Abel, Gustav Fröhlich, Rudolf Klein-Rogge, Fritz Rasp, Theodor Loos, Erwin Biswanger, Heinrich George, Brigitte Helm</td><td>In a futuristic city sharply divided between the working class and the city planners, the son of the city's mastermind falls in love with a working class prophet who predicts the coming of a savior to mediate their differences.</td><td>08.mar</td><td>156076</td><td>DEM 6000000</td><td>$ 1236166</td><td>$ 1349711</td><td>98.0</td><td>495.0</td><td>208.0</td><td>1742317980</td><td>98.0</td><td>6000000</td></tr><tr><td>tt0021749</td><td>Luci della città</td><td>City Lights</td><td>1931</td><td>02.04.1931</td><td>Comedy, Drama, Romance</td><td>87</td><td>USA</td><td>English</td><td>Charles Chaplin</td><td>Charles Chaplin</td><td>Charles Chaplin Productions</td><td>Virginia Cherrill, Florence Lee, Harry Myers, Al Ernest Garcia, Hank Mann, Charles Chaplin</td><td>With the aid of a wealthy erratic tippler, a dewy-eyed tramp who has fallen in love with a sightless flower girl accumulates money to be able to help her medically.</td><td>08.maj</td><td>162668</td><td>$ 1500000</td><td>$ 19181</td><td>$ 46008</td><td>99.0</td><td>295.0</td><td>122.0</td><td>1742317980</td><td>94.0</td><td>1500000</td></tr><tr><td>tt0027977</td><td>Tempi moderni</td><td>Modern Times</td><td>1936</td><td>12.03.1937</td><td>Comedy, Drama, Family</td><td>87</td><td>USA</td><td>English</td><td>Charles Chaplin</td><td>Charles Chaplin</td><td>Charles Chaplin Productions</td><td>Charles Chaplin, Paulette Goddard, Henry Bergman, Tiny Sandford, Chester Conklin, Hank Mann, Stanley Blystone, Al Ernest Garcia, Richard Alexander, Cecil Reynolds, Mira McKinney, Murdock MacQuarrie, Wilfred Lucas, Edward LeSaint, Fred Malatesta</td><td>The Tramp struggles to live in modern industrial society with the help of a young homeless woman.</td><td>08.maj</td><td>211250</td><td>$ 1500000</td><td>$ 163577</td><td>$ 457688</td><td>96.0</td><td>307.0</td><td>115.0</td><td>1742317980</td><td>89.0</td><td>1500000</td></tr><tr><td>tt0029453</td><td>Il bandito della Casbah</td><td>Pépé le Moko</td><td>1937</td><td>22.10.1937</td><td>Crime, Drama, Romance</td><td>94</td><td>France</td><td>French, Arabic</td><td>Julien Duvivier</td><td>Henri La Barthe, Henri La Barthe</td><td>Paris Film</td><td>Jean Gabin, Gabriel Gabrio, Saturnin Fabre, Fernand Charpin, Lucas Gridoux, Gilbert Gil, Marcel Dalio, Charles Granval, Gaston Modot, René Bergeron, Paul Escoffier, Roger Legris, Jean Témerson, Robert Ozanne, Philippe Richard</td><td>A wanted gangster is both king and prisoner of the Casbah. He is protected from arrest by his friends, but is torn by his desire for freedom outside. A visiting Parisian beauty may just tempt his fate.</td><td>07.lip</td><td>6180</td><td>$ 60000</td><td>$ 155895</td><td>$ 155895</td><td>98.0</td><td>46.0</td><td>55.0</td><td>1742317980</td><td>88.0</td><td>60000</td></tr><tr><td>tt0029583</td><td>Biancaneve e i sette nani</td><td>Snow White and the Seven Dwarfs</td><td>1937</td><td>30.11.1938</td><td>Animation, Family, Fantasy</td><td>83</td><td>USA</td><td>English</td><td>William Cottre ...
# == Parsed Logical Plan ==
# Filter atleastnnonnulls(25, imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, execution_time#11947, ... 2 more fields)
# +- Project [imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, execution_time#11947, age#11972, regexp_replace(budget#11919, [^\d.], , 1) AS budget_number#11997]
#    +- Project [imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, execution_time#11947, CASE WHEN isnotnull(year#11906) THEN (cast(year(current_date(Some(Etc/UTC))) as double) - cast(year#11906 as double)) ELSE cast(null as double) END AS age#11972]
#       +- Project [imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, 1742317980 AS execution_time#11947]
#          +- Relation [imdb_title_id#11903,title#11904,original_title#11905,year#11906,date_published#11907,genre#11908,duration#11909,country#11910,language#11911,director#11912,writer#11913,production_company#11914,actors#11915,description#11916,avg_vote#11917,votes#11918,budget#11919,usa_gross_income#11920,worlwide_gross_income#11921,metascore#11922,reviews_from_users#11923,reviews_from_critics#11924] csv
#
# == Analyzed Logical Plan ==
# imdb_title_id: string, title: string, original_title: string, year: string, date_published: string, genre: string, duration: int, country: string, language: string, director: string, writer: string, production_company: string, actors: string, description: string, avg_vote: string, votes: int, budget: string, usa_gross_income: string, worlwide_gross_income: string, metascore: double, reviews_from_users: double, reviews_from_critics: double, execution_time: int, age: double, budget_number: string
# Filter atleastnnonnulls(25, imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, execution_time#11947, ... 2 more fields)
# +- Project [imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, execution_time#11947, age#11972, regexp_replace(budget#11919, [^\d.], , 1) AS budget_number#11997]
#    +- Project [imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, execution_time#11947, CASE WHEN isnotnull(year#11906) THEN (cast(year(current_date(Some(Etc/UTC))) as double) - cast(year#11906 as double)) ELSE cast(null as double) END AS age#11972]
#       +- Project [imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, 1742317980 AS execution_time#11947]
#          +- Relation [imdb_title_id#11903,title#11904,original_title#11905,year#11906,date_published#11907,genre#11908,duration#11909,country#11910,language#11911,director#11912,writer#11913,production_company#11914,actors#11915,description#11916,avg_vote#11917,votes#11918,budget#11919,usa_gross_income#11920,worlwide_gross_income#11921,metascore#11922,reviews_from_users#11923,reviews_from_critics#11924] csv
#
# == Optimized Logical Plan ==
# Project [imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, 1742317980 AS execution_time#11947, CASE WHEN isnotnull(year#11906) THEN (2025.0 - cast(year#11906 as double)) END AS age#11972, regexp_replace(budget#11919, [^\d.], , 1) AS budget_number#11997]
# +- Filter atleastnnonnulls(24, imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, CASE WHEN isnotnull(year#11906) THEN (2025.0 - cast(year#11906 as double)) END, regexp_replace(budget#11919, [^\d.], , 1))
#    +- Relation [imdb_title_id#11903,title#11904,original_title#11905,year#11906,date_published#11907,genre#11908,duration#11909,country#11910,language#11911,director#11912,writer#11913,production_company#11914,actors#11915,description#11916,avg_vote#11917,votes#11918,budget#11919,usa_gross_income#11920,worlwide_gross_income#11921,metascore#11922,reviews_from_users#11923,reviews_from_critics#11924] csv
#
# == Physical Plan ==
# *(1) Project [imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, 1742317980 AS execution_time#11947, CASE WHEN isnotnull(year#11906) THEN (2025.0 - cast(year#11906 as double)) END AS age#11972, regexp_replace(budget#11919, [^\d.], , 1) AS budget_number#11997]
# +- *(1) Filter atleastnnonnulls(24, imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_published#11907, genre#11908, duration#11909, country#11910, language#11911, director#11912, writer#11913, production_company#11914, actors#11915, description#11916, avg_vote#11917, votes#11918, budget#11919, usa_gross_income#11920, worlwide_gross_income#11921, metascore#11922, reviews_from_users#11923, reviews_from_critics#11924, CASE WHEN isnotnull(year#11906) THEN (2025.0 - cast(year#11906 as double)) END, regexp_replace(budget#11919, [^\d.], , 1))
#    +- FileScan csv [imdb_title_id#11903,title#11904,original_title#11905,year#11906,date_published#11907,genre#11908,duration#11909,country#11910,language#11911,director#11912,writer#11913,production_company#11914,actors#11915,description#11916,avg_vote#11917,votes#11918,budget#11919,usa_gross_income#11920,worlwide_gross_income#11921,metascore#11922,reviews_from_users#11923,reviews_from_critics#11924] Batched: false, DataFilters: [atleastnnonnulls(24, imdb_title_id#11903, title#11904, original_title#11905, year#11906, date_pu..., Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/FileStore/tables/Files/movies.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<imdb_title_id:string,title:string,original_title:string,year:string,date_published:string,...

# %% [markdown]
# ratings.csv
# * Dodaj kolumnę z wartością czasu wykonania notatnika w formacie epoch
# * Dla każdego z poniższych wyliczeń nie bierz pod uwagę `nulls`
# * Kto daje lepsze oceny chłopcy czy dziewczyny dla całego setu
# * Dla jednej z kolumn zmień typ danych do `long`

# %%
from pyspark.sql.types import LongType

# %%
filePath = "dbfs:/FileStore/tables/Files/ratings.csv"
ratingsDf = (spark.read.format("csv")
              .option("header","true")
              .option("inferSchema","true")
              .load(filePath))

current_epoch = int(time.time())
ratingsDf = ratingsDf.withColumn("execution_time", fun.lit(current_epoch))

#avg automatycznie usunie nulla
males = ratingsDf.select(fun.avg('males_allages_avg_vote')).collect()[0][0]
females = ratingsDf.select(fun.avg('females_allages_avg_vote')).collect()[0][0]
display("males avg: ", males, " females avg: ", females)

ratingsDf = ratingsDf.withColumn(
    'execution_time', fun.when(ratingsDf['execution_time'].isNotNull(), 
    ratingsDf['execution_time'].cast(LongType())).otherwise(None)
)

display(ratingsDf.limit(20))
ratingsDf.explain(True)
# Out:
# 'males avg: '5.817172176019753' females avg: '6.03940821227877
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>imdb_title_id</th><th>weighted_average_vote</th><th>total_votes</th><th>mean_vote</th><th>median_vote</th><th>votes_10</th><th>votes_9</th><th>votes_8</th><th>votes_7</th><th>votes_6</th><th>votes_5</th><th>votes_4</th><th>votes_3</th><th>votes_2</th><th>votes_1</th><th>allgenders_0age_avg_vote</th><th>allgenders_0age_votes</th><th>allgenders_18age_avg_vote</th><th>allgenders_18age_votes</th><th>allgenders_30age_avg_vote</th><th>allgenders_30age_votes</th><th>allgenders_45age_avg_vote</th><th>allgenders_45age_votes</th><th>males_allages_avg_vote</th><th>males_allages_votes</th><th>males_0age_avg_vote</th><th>males_0age_votes</th><th>males_18age_avg_vote</th><th>males_18age_votes</th><th>males_30age_avg_vote</th><th>males_30age_votes</th><th>males_45age_avg_vote</th><th>males_45age_votes</th><th>females_allages_avg_vote</th><th>females_allages_votes</th><th>females_0age_avg_vote</th><th>females_0age_votes</th><th>females_18age_avg_vote</th><th>females_18age_votes</th><th>females_30age_avg_vote</th><th>females_30age_votes</th><th>females_45age_avg_vote</th><th>females_45age_votes</th><th>top1000_voters_rating</th><th>top1000_voters_votes</th><th>us_voters_rating</th><th>us_voters_votes</th><th>non_us_voters_rating</th><th>non_us_voters_votes</th><th>execution_time</th></tr></thead><tbody><tr><td>tt0000009</td><td>5.9</td><td>154</td><td>5.9</td><td>6.0</td><td>12</td><td>4</td><td>10</td><td>43</td><td>28</td><td>28</td><td>9</td><td>1</td><td>5</td><td>14</td><td>7.2</td><td>4.0</td><td>6.0</td><td>38.0</td><td>5.7</td><td>50.0</td><td>6.6</td><td>35.0</td><td>6.2</td><td>97.0</td><td>7.0</td><td>1.0</td><td>5.9</td><td>24.0</td><td>5.6</td><td>36.0</td><td>6.7</td><td>31.0</td><td>6.0</td><td>35.0</td><td>7.3</td><td>3.0</td><td>5.9</td><td>14.0</td><td>
# +- Project [imdb_title_id#12138, weighted_average_vote#12139, total_votes#12140, mean_vote#12141, median_vote#12142, votes_10#12143, votes_9#12144, votes_8#12145, votes_7#12146, votes_6#12147, votes_5#12148, votes_4#12149, votes_3#12150, votes_2#12151, votes_1#12152, allgenders_0age_avg_vote#12153, allgenders_0age_votes#12154, allgenders_18age_avg_vote#12155, allgenders_18age_votes#12156, allgenders_30age_avg_vote#12157, allgenders_30age_votes#12158, allgenders_45age_avg_vote#12159, allgenders_45age_votes#12160, males_allages_avg_vote#12161, ... 26 more fields]
#    +- Relation [imdb_title_id#12138,weighted_average_vote#12139,total_votes#12140,mean_vote#12141,median_vote#12142,votes_10#12143,votes_9#12144,votes_8#12145,votes_7#12146,votes_6#12147,votes_5#12148,votes_4#12149,votes_3#12150,votes_2#12151,votes_1#12152,allgenders_0age_avg_vote#12153,allgenders_0age_votes#12154,allgenders_18age_avg_vote#12155,allgenders_18age_votes#12156,allgenders_30age_avg_vote#12157,allgenders_30age_votes#12158,allgenders_45age_avg_vote#12159,allgenders_45age_votes#12160,males_allages_avg_vote#12161,... 25 more fields] csv
#
# == Analyzed Logical Plan ==
# imdb_title_id: string, weighted_average_vote: double, total_votes: int, mean_vote: double, median_vote: double, votes_10: int, votes_9: int, votes_8: int, votes_7: int, votes_6: int, votes_5: int, votes_4: int, votes_3: int, votes_2: int, votes_1: int, allgenders_0age_avg_vote: double, allgenders_0age_votes: double, allgenders_18age_avg_vote: double, allgenders_18age_votes: double, allgenders_30age_avg_vote: double, allgenders_30age_votes: double, allgenders_45age_avg_vote: double, allgenders_45age_votes: double, males_allages_avg_vote: double, ... 26 more fields
# Project [imdb_title_id#12138, weighted_average_vote#12139, total_votes#12140, mean_vote#12141, median_vote#12142, votes_10#12143, votes_9#12144, votes_8#12145, votes_7#12146, votes_6#12147, votes_5#12148, votes_4#12149, votes_3#12150, votes_2#12151, votes_1#12152, allgenders_0age_avg_vote#12153, allgenders_0age_votes#12154, allgenders_18age_avg_vote#12155, allgenders_18age_votes#12156, allgenders_30age_avg_vote#12157, allgenders_30age_votes#12158, allgenders_45age_avg_vote#12159, allgenders_45age_votes#12160, males_allages_avg_vote#12161, ... 26 more fields]
# +- Project [imdb_title_id#12138, weighted_average_vote#12139, total_votes#12140, mean_vote#12141, median_vote#12142, votes_10#12143, votes_9#12144, votes_8#12145, votes_7#12146, votes_6#12147, votes_5#12148, votes_4#12149, votes_3#12150, votes_2#12151, votes_1#12152, allgenders_0age_avg_vote#12153, allgenders_0age_votes#12154, allgenders_18age_avg_vote#12155, allgenders_18age_votes#12156, allgenders_30age_avg_vote#12157, allgenders_30age_votes#12158, allgenders_45age_avg_vote#12159, allgenders_45age_votes#12160, males_allages_avg_vote#12161, ... 26 more fields]
#    +- Relation [imdb_title_id#12138,weighted_average_vote#12139,total_votes#12140,mean_vote#12141,median_vote#12142,votes_10#12143,votes_9#12144,votes_8#12145,votes_7#12146,votes_6#12147,votes_5#12148,votes_4#12149,votes_3#12150,votes_2#12151,votes_1#12152,allgenders_0age_avg_vote#12153,allgenders_0age_votes#12154,allgenders_18age_avg_vote#12155,allgenders_18age_votes#12156,allgenders_30age_avg_vote#12157,allgenders_30age_votes#12158,allgenders_45age_avg_vote#12159,allgenders_45age_votes#12160,males_allages_avg_vote#12161,... 25 more fields] csv
#
# == Optimized Logical Plan ==
# Project [imdb_title_id#12138, weighted_average_vote#12139, total_votes#12140, mean_vote#12141, median_vote#12142, votes_10#12143, votes_9#12144, votes_8#12145, votes_7#12146, votes_6#12147, votes_5#12148, votes_4#12149, votes_3#12150, votes_2#12151, votes_1#12152, allgenders_0age_avg_vote#12153, allgenders_0age_votes#12154, allgenders_18age_avg_vote#12155, allgenders_18age_votes#12156, allgenders_30age_avg_vote#12157, allgenders_30age_votes#12158, allgenders_45age_avg_vote#12159, allgenders_45age_votes#12160, males_allages_avg_vote#12161, ... 26 more fields]
# +- Relation [imdb_title_id#12138,weighted_average_vote#12139,total_votes#12140,mean_vote#12141,median_vote#12142,votes_10#12143,votes_9#12144,votes_8#12145,votes_7#12146,votes_6#12147,votes_5#12148,votes_4#12149,votes_3#12150,votes_2#12151,votes_1#12152,allgenders_0age_avg_vote#12153,allgenders_0age_votes#12154,allgenders_18age_avg_vote#12155,allgenders_18age_votes#12156,allgenders_30age_avg_vote#12157,allgenders_30age_votes#12158,allgenders_45age_avg_vote#12159,allgenders_45age_votes#12160,males_allages_avg_vote#12161,... 25 more fields] csv
#
# == Physical Plan ==
# *(1) Project [imdb_title_id#12138, weighted_average_vote#12139, total_votes#12140, mean_vote#12141, median_vote#12142, votes_10#12143, votes_9#12144, votes_8#12145, votes_7#12146, votes_6#12147, votes_5#12148, votes_4#12149, votes_3#12150, votes_2#12151, votes_1#12152, allgenders_0age_avg_vote#12153, allgenders_0age_votes#12154, allgenders_18age_avg_vote#12155, allgenders_18age_votes#12156, allgenders_30age_avg_vote#12157, allgenders_30age_votes#12158, allgenders_45age_avg_vote#12159, allgenders_45age_votes#12160, males_allages_avg_vote#12161, ... 26 more fields]
# +- FileScan csv [imdb_title_id#12138,weighted_average_vote#12139,total_votes#12140,mean_vote#12141,median_vote#12142,votes_10#12143,votes_9#12144,votes_8#12145,votes_7#12146,votes_6#12147,votes_5#12148,votes_4#12149,votes_3#12150,votes_2#12151,votes_1#12152,allgenders_0age_avg_vote#12153,allgenders_0age_votes#12154,allgenders_18age_avg_vote#12155,allgenders_18age_votes#12156,allgenders_30age_avg_vote#12157,allgenders_30age_votes#12158,allgenders_45age_avg_vote#12159,allgenders_45age_votes#12160,males_allages_avg_vote#12161,... 25 more fields] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/FileStore/tables/Files/ratings.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<imdb_title_id:string,weighted_average_vote:double,total_votes:int,mean_vote:double,median_...
